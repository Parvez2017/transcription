# %%
from  pysubtitle import Subtile
from pys3 import Awss3
from pytranscrib import Transcib
import os 
import glob 
import re 


path = 'trump'
files = glob.glob('trump/*.mp4')
files = sorted(files, key=lambda x:float(re.findall("(\d+)",x)[0]))

for file in files:
    basename = os.path.basename(file).split('.')[0]
    s3 = Awss3(aws_access_key_id='AKIAVQ4O4UA5EIJ5NMIW', aws_secret_access_key='XsQ2hUfvhU92abzpVHJdquTTO6gukhLX8Jp6ZDIG')
    audio_file = s3.video2audio(file, basename)

    new_bucket = 'ticon-deep-fake-video'
    #print(s3.create_bucket(new_bucket))
    # print(s3.s3_bucketlist())

    s3_file = s3.upload_file(new_bucket, f'{basename}.wav', basename)
    print(s3_file)

    trancrib = Transcib(bucket=new_bucket, aws_access_key_id='AKIAVQ4O4UA5EIJ5NMIW', aws_secret_access_key='XsQ2hUfvhU92abzpVHJdquTTO6gukhLX8Jp6ZDIG')
    print(trancrib.transcribjob(f's3://ticon-deep-fake-video/{basename}.wav', 'en-US'))
#     sub = Subtile(f'{basename}.json')
#     sub.transcribe(f'{basename}.wav')
#     print('transcription done!...')
# Out:
# chunk:   0%|          | 66/75193 [00:00<01:53, 659.06it/s, now=None]
# MoviePy - Writing audio in trump8.wav
# MoviePy - Done.
# {'status': 'S3 Upload Success', 'filename': 'trump8.wav', 's3_url': 's3://ticon-deep-fake-video/trump8.wav', 's3_region': 'ap-southeast-1'}
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# Generate Json File: IN_PROGRESS
# ...
